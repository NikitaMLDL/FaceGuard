# %%
import mlflow
# from faiss_service import VectorDBService
from routes import get_embedding_from_image
import numpy as np
import os
import time
from typing import List
from facenet_pytorch import MTCNN, InceptionResnetV1

# Устанавливаем URI для MLflow, чтобы использовать локальный сервер
mlflow.set_tracking_uri('http://127.0.0.1:5000')

# Устанавливаем название эксперимента
mlflow.set_experiment('Face_Recognition_Experiment 2')  # Название эксперимента
# Out:
# 2025/04/04 00:05:20 INFO mlflow.tracking.fluent: Experiment with name 'Face_Recognition_Experiment 2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/727893366955203987', creation_time=1743714320297, experiment_id='727893366955203987', last_update_time=1743714320297, lifecycle_stage='active', name='Face_Recognition_Experiment 2', tags={}>

# %%
mtcnn = MTCNN()
resnet = InceptionResnetV1(pretrained='casia-webface').eval()

# %%
def extract_embeddings_from_folder(folder_path: str) -> List[np.ndarray]:
    embeddings = []
    labels = []

    # Получаем список всех папок в folder_path
    subfolders = [f.path for f in os.scandir(folder_path) if f.is_dir()]

    # Ограничиваемся только первыми тремя папками
    subfolders = subfolders[:3]

    for folder in subfolders:
        # Получаем список файлов в папке и выбираем первый файл изображения
        image_files = [f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

        # Если папка содержит изображения, выбираем первое
        if image_files:
            image_path = os.path.join(folder, image_files[0])

            with open(image_path, 'rb') as f:
                image_bytes = f.read()
                embedding = get_embedding_from_image(image_bytes)

                # Используем имя папки как метку
                label = os.path.basename(folder)

                embeddings.append(embedding)
                labels.append(label)

    print('Закончили извлечение эмбеддингов')
    return np.array(embeddings), labels

# %%
import faiss
import numpy as np
import os
import logging
from typing import List

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


class VectorDBService:
    """
    Class for working with a FAISS database using cosine similarity.
    """

    def __init__(self, index_file_path: str = "faiss_index.index", dim: int = 512):
        """
        Initializes the FAISS database.

        :param index_file_path: Path to the file for saving the index.
        :param dim: Dimensionality of the embeddings.
        """
        logger.info(f"Index path: {index_file_path}")
        self.index_file_path = index_file_path
        self.dim = dim
        self.index = None
        self.load_index()

    def load_index(self):
        """
        Loads the index from a file if it exists.
        If the index file does not exist, a new index is created.
        """
        if os.path.exists(self.index_file_path):
            try:
                self.index = faiss.read_index(self.index_file_path)
                if self.index.metric_type != faiss.METRIC_INNER_PRODUCT:
                    logger.warning("Loaded index is not using inner product metric! Rebuilding...")
                    self.index = faiss.IndexFlatIP(self.dim)
                logger.info(f"Index loaded from {self.index_file_path}")
            except Exception as e:
                logger.error(f"Failed to load index: {str(e)}")
                self.index = faiss.IndexFlatIP(self.dim)
        else:
            self.index = faiss.IndexFlatIP(self.dim)

    def save_index(self):
        """
        Saves the index to a file.
        """
        try:
            faiss.write_index(self.index, self.index_file_path)
            logger.info(f"Index saved to {self.index_file_path}")
        except Exception as e:
            logger.error(f"Error saving index: {str(e)}")

    def add_embeddings(self, embeddings: np.ndarray):
        """
        Adds embeddings to FAISS.

        :param embeddings: Embedding vectors to be added.
        """
        try:
            embeddings = embeddings.astype(np.float32)
            faiss.normalize_L2(embeddings)  # Normalize embeddings
            self.index.add(embeddings)
            logger.info(f"Added {embeddings.shape[0]} embeddings to FAISS.")
            self.save_index()
        except Exception as e:
            logger.error(f"Error adding embeddings to FAISS: {str(e)}")

    def search_embedding(self, embedding: np.ndarray, k: int = 1, threshold: float = 0.6) -> List[int]:
        """
        Searches for the most similar embeddings in FAISS using cosine similarity.

        :param embedding: Embedding to search for.
        :param k: Number of nearest neighbors.
        :param threshold: Distance threshold (values closer to 0 are more similar).
        :return: List of indices of found embeddings that meet the threshold.
        """
        try:
            embedding = embedding.astype(np.float32).reshape(1, -1)
            faiss.normalize_L2(embedding)

            distances, indices = self.index.search(embedding, k)

            # Convert similarity score (inner product) to cosine distance (1 - similarity)
            cosine_distances = 1 - distances

            logger.info("Cosine Distances: %s, Indices: %s", cosine_distances, indices)

            # Filter by threshold (distances should be <= threshold for similarity)
            valid_indices = [idx for dist, idx in zip(cosine_distances[0], indices[0]) if dist <= threshold]

            if valid_indices:
                logger.info(f"Found {len(valid_indices)} nearest neighbors: {valid_indices}")
                return valid_indices
            else:
                logger.info("No embeddings found within the threshold.")
                return [-1]  # If no embedding passes the threshold, return -1

        except Exception as e:
            logger.error(f"Error searching in FAISS: {str(e)}")
            return []

    def remove_embedding_by_embedding(self, embedding: np.ndarray):
        """
        Removes an embedding from FAISS if it exists.

        :param embedding: Embedding vector to remove.
        """
        try:
            if self.index.ntotal == 0:
                logger.error("FAISS index is empty. Nothing to remove.")
                return

            embedding = embedding.astype(np.float32).reshape(1, -1)
            faiss.normalize_L2(embedding)

            _, indices = self.index.search(embedding, 1)  # Find the closest match
            idx = indices[0][0]

            if idx == -1:
                logger.error("Embedding not found in FAISS. No changes made.")
                return

            # Get all embeddings, remove the found one
            embeddings = self.index.reconstruct_n(0, self.index.ntotal)
            embeddings = np.delete(embeddings, idx, axis=0)

            # Rebuild index with remaining embeddings
            self.index = faiss.IndexFlatIP(self.dim)
            faiss.normalize_L2(embeddings)  # Normalize before re-adding
            self.index.add(embeddings)

            logger.info(f"Removed embedding at index {idx}.")
            self.save_index()

        except Exception as e:
            logger.error(f"Error removing embedding: {str(e)}")

# %%
data_folder = "Original Images"  # Папка с изображениями для тренировки

# Извлечение эмбеддингов из папки данных и добавление их в индекс
train_embeddings, labels = extract_embeddings_from_folder(data_folder)
# Out:
# Закончили извлечение эмбеддингов

# %%
labels
# Out:
# ['Akshay Kumar', 'Alexandra Daddario', 'Alia Bhatt']

# %%
len(train_embeddings)
# Out:
# 3

# %%
# Создание индекса FAISS
index_service = VectorDBService()
index_service.add_embeddings(train_embeddings)
# Out:
# INFO:__main__:Index path: faiss_index.index
# INFO:__main__:Added 3 embeddings to FAISS.
# INFO:__main__:Index saved to faiss_index.index

# %%
# Пороги для поиска
thresholds = [0.2, 0.5, 0.7]  # Пример пороговых значений

# %%
import gc
gc.collect()  # Сборщик мусора для освобождения памяти
# Out:
# 1555

# %% [markdown]
# # baseline

# %%
import os
import time
import numpy as np
import mlflow
import matplotlib.pyplot as plt
from typing import List

def evaluate_accuracy_and_speed(query_folder: str, index_service, labels: List[str], thresholds: List[float], k=5):
    correct = {threshold: 0 for threshold in thresholds}
    total_queries = {threshold: 0 for threshold in thresholds}
    times = {threshold: [] for threshold in thresholds}
    accuracy_progress = {threshold: [] for threshold in thresholds}

    subfolders = [f.path for f in os.scandir(query_folder) if f.is_dir()][:3]
    
    with mlflow.start_run():
        for threshold in thresholds:
            with mlflow.start_run(nested=True):
                print(f'Оценка с порогом: {threshold}')
                mlflow.log_param("threshold", threshold)
                
                for folder in subfolders:
                    for image_file in os.listdir(folder):
                        image_path = os.path.join(folder, image_file)
                        
                        if image_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                            with open(image_path, 'rb') as f:
                                image_bytes = f.read()
                                query_embedding = get_embedding_from_image(image_bytes)

                                start_time = time.time()
                                found_indices = index_service.search_embedding(query_embedding, k=k, threshold=threshold)
                                elapsed_time = time.time() - start_time
                                times[threshold].append(elapsed_time)

                                found_labels = [labels[i] for i in found_indices]
                                if image_file.split('_')[0] in found_labels:
                                    correct[threshold] += 1
                                total_queries[threshold] += 1

                                accuracy_progress[threshold].append(correct[threshold])
                
                # Нормализация точности на общее количество итераций
                normalized_accuracy = [acc / total_queries[threshold] for acc in accuracy_progress[threshold]]
                
                # Логирование точности на каждой итерации
                for iteration in range(len(normalized_accuracy)):
                    mlflow.log_metric(f'accuracy_{threshold}', normalized_accuracy[iteration], step=iteration)
                
                # Построение и сохранение графика нормализованной точности
                plt.figure()
                plt.plot(normalized_accuracy, label=f'Threshold {threshold}')
                plt.xlabel("Iterations")
                plt.ylabel("Normalized Accuracy")
                plt.legend()
                plt.title(f"Normalized Accuracy Progress (Threshold {threshold})")
                plot_path = f"normalized_accuracy_progress_{threshold}.png"
                plt.savefig(plot_path)
                plt.close()
                mlflow.log_artifact(plot_path)

        accuracy = {threshold: correct[threshold] / total_queries[threshold] if total_queries[threshold] else 0 for threshold in thresholds}
        average_time = {threshold: np.mean(times[threshold]) for threshold in thresholds}
        
        for threshold in thresholds:
            mlflow.log_metric(f"accuracy_{threshold}_final", accuracy[threshold] * 100)
            mlflow.log_metric(f"average_search_time_{threshold}", average_time[threshold])

    return accuracy, average_time

# %%
evaluate_accuracy_and_speed(data_folder, index_service, labels, thresholds=thresholds, k=1)
# Out:
# Оценка с порогом: 0.2
# INFO:__main__:Cosine Distances: [[-1.1920929e-07]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.42853034]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46904683]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6369537]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49379462]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2196247]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38904196]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40139192]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41364413]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40038925]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44898403]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4464817]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5457547]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2953266]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5334995]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4193344]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.18537211]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5934052]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4472555]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40382016]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39083815]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5269639]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5215517]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5772355]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.496814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39214098]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.64408803]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.71389824]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39361632]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39670503]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43563533]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50243413]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.22570485]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30748057]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43474972]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.33735454]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4747187]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37917012]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37841648]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3510114]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41873777]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# 🏃 View run spiffy-elk-328 at: http://127.0.0.1:5000/#/experiments/968677774182020642/runs/c7a09ca2ba554689afeb8141dfd91e43
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/968677774182020642
# Оценка с порогом: 0.5
# INFO:__main__:Cosine Distances: [[-1.1920929e-07]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.42853034]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.46904683]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.6369537]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49379462]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2196247]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.38904196]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.40139192]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.41364413]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40038925]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.44898403]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4464817]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5457547]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2953266]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5334995]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4193344]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.18537211]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5934052]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4472555]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40382016]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39083815]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5269639]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5215517]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5772355]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.496814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39214098]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.64408803]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.71389824]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39361632]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39670503]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43563533]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.50243413]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# ...
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.22570485]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30748057]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43474972]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.33735454]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4747187]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37917012]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37841648]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3510114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41873777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# 🏃 View run resilient-frog-188 at: http://127.0.0.1:5000/#/experiments/968677774182020642/runs/dec439eb4c2d421cbd25be7b95d6fb5e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/968677774182020642
# 🏃 View run overjoyed-chimp-472 at: http://127.0.0.1:5000/#/experiments/968677774182020642/runs/2982e7a87ee048228b4d2b6f2c3634f0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/968677774182020642
# ({0.2: 0.37104072398190047, 0.5: 0.7782805429864253, 0.7: 0.9864253393665159},
#  {0.2: 0.0020625170539407167,
#   0.5: 0.002133338160104881,
#   0.7: 0.0023433644307684575})

# %% [markdown]
# # shuffle

# %%
import os
import shutil
import random

# %%
source_folder = 'Original Images'  # Путь к вашей папке с подпапками
shuffled_folder = 'Shuffled'    # Путь для новой папки перемешанных изображений

if not os.path.exists(shuffled_folder):
        os.makedirs(shuffled_folder)

# Получаем список всех подпапок (папок с лицами)
subfolders = [f.path for f in os.scandir(source_folder) if f.is_dir()][:3]

# Список для хранения изображений
image_files = []

# Проходим по всем подпапкам и собираем все изображения
for subfolder in subfolders:
    for image_file in os.listdir(subfolder):
        if image_file.lower().endswith(('.jpg', '.jpeg', '.png')):
            # Сохраняем путь к изображению и его имя
            image_files.append(os.path.join(subfolder, image_file))

# Перемешиваем список изображений
random.shuffle(image_files)

# %%
for index, image_path in enumerate(image_files):
    # Получаем имя файла из пути
    image_name = os.path.basename(image_path)
    # Строим новый путь для файла в целевой папке
    target_path = os.path.join(shuffled_folder, f"{index + 1}_{image_name}")  # Добавим индекс для уникальности
    # Копируем файл
    shutil.copy(image_path, target_path)

print(f'Все изображения успешно перемешаны и скопированы в {shuffled_folder}')
# Out:
# Все изображения успешно перемешаны и скопированы в Shuffled

# %%
import os
import time
import numpy as np
import mlflow
import matplotlib.pyplot as plt
from typing import List

def evaluate_accuracy_and_speed(query_folder: str, index_service, labels: List[str], thresholds: List[float], k=5):
    correct = {threshold: 0 for threshold in thresholds}
    total_queries = {threshold: 0 for threshold in thresholds}
    times = {threshold: [] for threshold in thresholds}
    accuracy_progress = {threshold: [] for threshold in thresholds}
    labels_n = [i for i in enumerate(labels)]
    with mlflow.start_run():
        for threshold in thresholds:
            with mlflow.start_run(nested=True):
                print(f'Оценка с порогом: {threshold}')
                mlflow.log_param("threshold", threshold)
                for image in os.listdir(query_folder):
                    image_file = os.path.join(shuffled_folder, image)
                    with open(image_path, 'rb') as f:
                        image_bytes = f.read()
                        query_embedding = get_embedding_from_image(image_bytes)

                        start_time = time.time()
                        found_indices = index_service.search_embedding(query_embedding, k=k, threshold=threshold)
                        elapsed_time = time.time() - start_time
                        times[threshold].append(elapsed_time)

                        if labels_n[found_indices[0]][1] in image_file:
                            correct[threshold] += 1
                        total_queries[threshold] += 1

                        accuracy_progress[threshold].append(correct[threshold])
                
                # Нормализация точности на общее количество итераций
                normalized_accuracy = [acc / total_queries[threshold] for acc in accuracy_progress[threshold]]
                
                # Логирование точности на каждой итерации
                for iteration in range(len(normalized_accuracy)):
                    mlflow.log_metric(f'accuracy', normalized_accuracy[iteration], step=iteration)
                
                # Построение и сохранение графика нормализованной точности
                plt.figure()
                plt.plot(normalized_accuracy, label=f'Threshold {threshold}')
                plt.xlabel("Iterations")
                plt.ylabel("Normalized Accuracy")
                plt.legend()
                plt.title(f"Normalized Accuracy Progress (Threshold {threshold})")
                plot_path = f"normalized_accuracy_progress_{threshold}.png"
                plt.savefig(plot_path)
                plt.close()
                mlflow.log_artifact(plot_path)

        accuracy = {threshold: correct[threshold] / total_queries[threshold] if total_queries[threshold] else 0 for threshold in thresholds}
        average_time = {threshold: np.mean(times[threshold]) for threshold in thresholds}
        
        for threshold in thresholds:
            mlflow.log_metric(f"accuracy_{threshold}_final", accuracy[threshold] * 100)
            mlflow.log_metric(f"average_search_time_{threshold}", average_time[threshold])

    return accuracy, average_time

# %%
evaluate_accuracy_and_speed(shuffled_folder, index_service, labels, thresholds=thresholds, k=1)

# %%
import os
import time
import mlflow
import matplotlib.pyplot as plt

# Примерная структура, функции get_embedding_from_image, index_service.search_embedding и т. д. предполагаются определенными где-то еще.

def run_query_experiment(query_folder, thresholds, labels, get_embedding_from_image, index_service):
    # Словари для хранения результатов
    correct = {threshold: 0 for threshold in thresholds}
    total_queries = {threshold: 0 for threshold in thresholds}
    times = {threshold: [] for threshold in thresholds}
    accuracy_progress = {threshold: [] for threshold in thresholds}
    
    labels_n = [i for i in enumerate(labels)]

    # Запуск эксперимента в MLflow
    with mlflow.start_run():
        mlflow.log_param("query_folder", query_folder)
        mlflow.log_param("thresholds", thresholds)

        # Для каждого порога точности
        for threshold in thresholds:
            mlflow.start_run(nested=True)  # Вложенный эксперимент для каждого порога
            mlflow.log_param("threshold", threshold)

            # Инициализация переменных для накопленной точности
            accumulated_correct = 0
            accumulated_total = 0

            # Для каждого изображения в папке query_folder
            for image in os.listdir(query_folder):
                image_file = os.path.join(query_folder, image)
                with open(image_file, 'rb') as f:
                    image_bytes = f.read()
                    query_embedding = get_embedding_from_image(image_bytes)

                    start_time = time.time()
                    found_indices = index_service.search_embedding(query_embedding, k=1, threshold=threshold)
                    elapsed_time = time.time() - start_time

                    # Сохраняем время
                    times[threshold].append(elapsed_time)
                    
                    # Проверка правильности
                    if labels_n[found_indices[0]][1] in image_file:
                        accumulated_correct += 1
                    accumulated_total += 1

                    # Накопленная точность
                    accumulated_accuracy = accumulated_correct / accumulated_total
                    accuracy_progress[threshold].append(accumulated_accuracy)

            # Нормализованная точность (весь список, а не одно значение на итерацию)
            normalized_accuracy = [acc / accumulated_total for acc in accuracy_progress[threshold]]

            # Логируем список нормализованной точности
            for iteration in range(len(normalized_accuracy)):
                if iteration == 0:
                    acc = normalized_accuracy[iteration]
                else:
                    acc = normalized_accuracy[iteration] + normalized_accuracy[iteration-1]
                    normalized_accuracy[iteration] = acc
                mlflow.log_metric(f'accuracy', acc, step=iteration)

            # Логируем график точности
            plt.figure()
            plt.plot(normalized_accuracy)
            plt.title(f"Normalized Accuracy Progress (Threshold {threshold})")
            plt.xlabel('Iterations')
            plt.ylabel('Normalized Accuracy')
            plt.savefig(f"accuracy_progress_{threshold}.png")
            mlflow.log_artifact(f"accuracy_progress_{threshold}.png")
            plt.close()

            mlflow.end_run()  # Закрытие вложенного эксперимента

        # Логируем данные по времени
        for threshold, elapsed_times in times.items():
            mlflow.log_metric(f"time_{threshold}", sum(elapsed_times) / len(elapsed_times))

    return correct, total_queries, times, accuracy_progress

# %%
result = run_query_experiment(query_folder='Shuffled', thresholds=[0.2, 0.5, 0.7], labels=labels, get_embedding_from_image=get_embedding_from_image, index_service=index_service)
# Out:
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43563533]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44898403]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.33735454]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.496814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5269639]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40038925]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[-1.1920929e-07]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40139192]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30748057]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5934052]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.71389824]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5215517]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46904683]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5334995]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43474972]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5457547]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39083815]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4193344]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39214098]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37917012]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37841648]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49379462]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4472555]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39670503]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3510114]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4747187]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41364413]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.64408803]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5772355]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2953266]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2196247]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4464817]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.22570485]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.40382016]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.6369537]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41873777]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.50243413]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39361632]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.42853034]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38904196]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.18537211]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# 🏃 View run fearless-auk-530 at: http://127.0.0.1:5000/#/experiments/727893366955203987/runs/3cd33f0ea8924bf287928b3a99e5e703
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/727893366955203987
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43563533]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44898403]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.33735454]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.496814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5269639]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.40038925]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[-1.1920929e-07]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40139192]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.30748057]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5934052]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.71389824]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5215517]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46904683]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5334995]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43474972]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5457547]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39083815]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4193344]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39214098]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37917012]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37841648]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.49379462]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4472555]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39670503]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3510114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4747187]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41364413]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.64408803]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5772355]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2953266]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.2196247]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4464817]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# ...
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:No embeddings found within the threshold.
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.22570485]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40382016]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6369537]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41873777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50243413]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39361632]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42853034]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.38904196]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.18537211]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# 🏃 View run gifted-crab-926 at: http://127.0.0.1:5000/#/experiments/727893366955203987/runs/957d901ef79f48b6a6840fbf416582c5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/727893366955203987
# 🏃 View run monumental-snail-668 at: http://127.0.0.1:5000/#/experiments/727893366955203987/runs/62b1886959244d40b26d4e61d277ffb8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/727893366955203987

# %%
mlflow.end_run()
# Out:
# 🏃 View run secretive-squid-254 at: http://127.0.0.1:5000/#/experiments/727893366955203987/runs/5771295aea2242688f060d225763e8b0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/727893366955203987
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 mlflow.end_run()
#
# File c:\Anaconda3\Lib\site-packages\mlflow\tracking\fluent.py:519, in end_run(status)
#     517 last_active_run_id = run.info.run_id
#     518 _last_active_run_id.set(last_active_run_id)
# --> 519 MlflowClient().set_terminated(last_active_run_id, status)
#     520 if last_active_run_id in run_id_to_system_metrics_monitor:
#     521     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(last_active_run_id)
#
# File c:\Anaconda3\Lib\site-packages\mlflow\tracking\client.py:2974, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    2929 def set_terminated(
#    2930     self, run_id: str, status: Optional[str] = None, end_time: Optional[int] = None
#    2931 ) -> None:
#    2932     """Set a run's status to terminated.
#    2933
#    2934     Args:
#    (...)
#    2972
#    2973     """
# -> 2974     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File c:\Anaconda3\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:1030, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#    1028 self.store.shut_down_async_logging()
#    1029 self._log_url(run_id)
# -> 1030 self.store.update_run_info(
#    1031     run_id,
#    1032     run_status=RunStatus.from_string(status),
#    1033     end_time=end_time,
#    1034     run_name=None,
#    1035 )
#
# File c:\Anaconda3\Lib\site-packages\mlflow\store\tracking\rest_store.py:191, in RestStore.update_run_info(self, run_id, run_status, end_time, run_name)
#     181 """Updates the metadata of the specified run."""
#     182 req_body = message_to_json(
#     183     UpdateRun(
#     184         run_uuid=run_id,
#    (...)
#     189     )
#     190 )
# --> 191 response_proto = self._call_endpoint(UpdateRun, req_body)
#     192 return RunInfo.from_proto(response_proto.run_info)
#
# File c:\Anaconda3\Lib\site-packages\mlflow\store\tracking\rest_store.py:90, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      88     endpoint, method = _METHOD_TO_INFO[api]
#      89 response_proto = api.Response()
# ---> 90 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Anaconda3\Lib\site-packages\mlflow\utils\rest_utils.py:392, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     389     call_kwargs["json"] = json_body
#     390     response = http_request(**call_kwargs)
# --> 392 response = verify_rest_response(response, endpoint)
#     393 response_to_parse = response.text
#     394 js_dict = json.loads(response_to_parse)
#
# File c:\Anaconda3\Lib\site-packages\mlflow\utils\rest_utils.py:249, in verify_rest_response(response, endpoint)
#     247 if response.status_code != 200:
#     248     if _can_parse_as_json_object(response.text):
# --> 249         raise RestException(json.loads(response.text))
#     250     else:
#     251         base_msg = (
#     252             f"API request to endpoint {endpoint} "
#     253             f"failed with error code {response.status_code} != 200"
#     254         )
#
# RestException: INVALID_PARAMETER_VALUE: The run 5771295aea2242688f060d225763e8b0 must be in 'active' lifecycle_stage.

# %%
query_folder = 'Shuffled'
threshold = 0.5
correct = {threshold: 0 for threshold in thresholds}
total_queries = {threshold: 0 for threshold in thresholds}
times = {threshold: [] for threshold in thresholds}
accuracy_progress = {threshold: [] for threshold in thresholds}
labels_n = [i for i in enumerate(labels)]
for image in os.listdir(query_folder):
    image_file = os.path.join(shuffled_folder, image)
    with open(image_file, 'rb') as f:
        image_bytes = f.read()
        query_embedding = get_embedding_from_image(image_bytes)

        start_time = time.time()
        found_indices = index_service.search_embedding(query_embedding, k=1, threshold=0.2)
        elapsed_time = time.time() - start_time
        times[threshold].append(elapsed_time)
        if labels_n[found_indices[0]][1] in image_file:
            correct[threshold] += 1
        total_queries[threshold] += 1
# Out:
# INFO:__main__:Cosine Distances: [[0.2890327]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43563533]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37183]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44898403]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.35572666]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.45631003]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.33735454]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4313804]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.409549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.496814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[-2.3841858e-07]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5269639]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.25814044]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.40038925]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[-1.1920929e-07]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.34424764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40139192]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.30748057]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.47766542]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.34050858]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49455512]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3047226]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5934052]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.71389824]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4336068]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5381764]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.41865695]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.415945]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5215517]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46799266]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5163088]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46904683]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.436871]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40968823]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6029744]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3791405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.45452094]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5334995]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.2791263]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.22694564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43474972]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30767703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5457547]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5810576]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39995933]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42415178]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38446534]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39083815]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4193344]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39214098]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.463583]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37917012]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37841648]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.343364]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.33076358]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3421439]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.49379462]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4472555]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39670503]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.8938973]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.26656657]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3824033]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3510114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3032031]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4747187]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39819646]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5502238]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.41364413]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.64408803]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.30420303]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.30280656]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5772355]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46236926]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.2953266]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.2196247]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4464817]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.58972394]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4358179]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48849827]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.493688]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.38932586]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.493999]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35630518]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.49138105]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3256963]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4239849]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5045593]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.518393]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39547694]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47774047]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.2678935]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34967506]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.466838]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4453746]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.37146652]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5365243]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4646327]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4166752]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37273222]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.45614314]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.29155755]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46546376]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.56213707]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.46013582]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40254354]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.42051572]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4293779]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.53322816]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5493567]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.44885594]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4131434]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28565097]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4772154]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4998504]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40365183]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.29085648]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5609802]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.43964136]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42483133]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4148764]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38308042]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41953242]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42253876]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47465718]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6159264]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4592464]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.30802405]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5748147]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.39563048]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.48330426]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4981674]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.37532294]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3567965]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50400716]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.35295582]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.34860063]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43620944]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.55383575]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.38778663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38970828]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3645655]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.40645748]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.61092454]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.52096814]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43180412]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.66638243]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.41311765]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.52224046]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5000587]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.53748626]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39418125]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.532169]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3650328]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5848959]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5704373]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.46584433]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5261684]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39115244]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.37786663]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48023176]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.56367767]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.3925892]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4064603]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4651265]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.24047297]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4096191]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5763339]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3523469]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.43457878]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.36508048]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5205549]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.55642325]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.3636585]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.46721274]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.44994187]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5115653]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35900998]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5480356]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.5597086]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4049257]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.5708809]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.36034614]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.591535]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.37367046]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.561293]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5242552]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.48395336]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.4337309]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.38484025]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.57680595]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.4792112]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.47263515]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43841565]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.86429065]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39906925]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3485629]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.5097761]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.53321564]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.35542703]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.42840236]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.22570485]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.28864777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3554424]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.40382016]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.6369537]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.39871693]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.41873777]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50695455]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.4500165]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.46960497]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.32887113]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.50243413]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.43711114]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.3750353]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.39361632]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
# INFO:__main__:Cosine Distances: [[0.42853034]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.38904196]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.18537211]], Indices: [[0]]
# INFO:__main__:Found 1 nearest neighbors: [0]
# INFO:__main__:Cosine Distances: [[0.35578275]], Indices: [[2]]
# INFO:__main__:Found 1 nearest neighbors: [2]
# INFO:__main__:Cosine Distances: [[0.48852324]], Indices: [[1]]
# INFO:__main__:Found 1 nearest neighbors: [1]
